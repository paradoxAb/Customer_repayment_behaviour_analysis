# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../application_record.csv")

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dt = pd.read_csv("../credit_record.csv")

# %%
dt
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
dd = pd.merge(df,dt,on="ID")

# %%
dd
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dd.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        240048
# CNT_FAM_MEMBERS             0
# MONTHS_BALANCE              0
# STATUS                      0
# dtype: int64

# %%
dd.fillna("Unknown",inplace=True)

# %%
dd
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dd.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# MONTHS_BALANCE           int64
# STATUS                  object
# dtype: object

# %%
df.CODE_GENDER.unique
# Out:
# <bound method Series.unique of 0         M
# 1         M
# 2         M
# 3         F
# 4         F
#          ..
# 438552    M
# 438553    F
# 438554    F
# 438555    F
# 438556    F
# Name: CODE_GENDER, Length: 438557, dtype: object>

# %%
df.FLAG_OWN_CAR.unique
# Out:
# <bound method Series.unique of 0         Y
# 1         Y
# 2         Y
# 3         N
# 4         N
#          ..
# 438552    N
# 438553    N
# 438554    N
# 438555    N
# 438556    N
# Name: FLAG_OWN_CAR, Length: 438557, dtype: object>

# %%
df.FLAG_OWN_REALTY.unique
# Out:
# <bound method Series.unique of 0         Y
# 1         Y
# 2         Y
# 3         Y
# 4         Y
#          ..
# 438552    Y
# 438553    N
# 438554    N
# 438555    Y
# 438556    Y
# Name: FLAG_OWN_REALTY, Length: 438557, dtype: object>

# %%
df.CNT_CHILDREN.unique
# Out:
# <bound method Series.unique of 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 438552    0
# 438553    0
# 438554    0
# 438555    0
# 438556    0
# Name: CNT_CHILDREN, Length: 438557, dtype: int64>

# %%
df.DAYS_EMPLOYED.unique
# Out:
# <bound method Series.unique of 0          -4542
# 1          -4542
# 2          -1134
# 3          -3051
# 4          -3051
#            ...
# 438552    365243
# 438553     -3007
# 438554      -372
# 438555    365243
# 438556     -1201
# Name: DAYS_EMPLOYED, Length: 438557, dtype: int64>

# %%
dd['CR_STATUS'] = dd.STATUS.map({'2':1,'3':1,'4':1,'5':1,'0':0,'C':0,'X':0,'1':0})

# %%
dd
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dd['Age'] = df['DAYS_BIRTH'] * (-1) / 365

# %%
dd.Age.astype
# Out:
# <bound method NDFrame.astype of 0         32.890411
# 1         32.890411
# 2         58.832877
# 3         52.356164
# 4         52.356164
#             ...
# 777710          NaN
# 777711          NaN
# 777712          NaN
# 777713          NaN
# 777714          NaN
# Name: Age, Length: 777715, dtype: float64>

# %%
dd.Age.fillna(0,inplace=True)

# %%
dd['Age'] = dd['Age'].astype('int64')

# %%
dd
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dd.Age.fillna(0,inplace=True)

# %%
dd.CR_STATUS.unique
# Out:
# <bound method Series.unique of 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 777710    0
# 777711    1
# 777712    0
# 777713    0
# 777714    0
# Name: CR_STATUS, Length: 777715, dtype: int64>

# %%
dd
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dd.FLAG_MOBIL.fillna(0)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 777710    1
# 777711    1
# 777712    1
# 777713    1
# 777714    1
# Name: FLAG_MOBIL, Length: 777715, dtype: int64

# %%
dd.CR_STATUS.astype('int64')
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 777710    0
# 777711    1
# 777712    0
# 777713    0
# 777714    0
# Name: CR_STATUS, Length: 777715, dtype: int64

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# CODE_GENDER            object
# FLAG_OWN_CAR           object
# FLAG_OWN_REALTY        object
# NAME_INCOME_TYPE       object
# NAME_EDUCATION_TYPE    object
# NAME_FAMILY_STATUS     object
# NAME_HOUSING_TYPE      object
# OCCUPATION_TYPE        object
# dtype: object

# %% [markdown]
# # EDA

# %% [markdown]
# ### What is the distribution of the Credit_Risk variable (Good (0) vs Bad (1))?

# %%
plt.figure(figsize=(6,4))
sb.countplot(x=dd['CR_STATUS'], data=df, palette='Set2')
plt.title("Distribution of Credit Risk")
plt.show()

# %% [markdown]
# ###  Which STATUS category occurs most frequently?

# %%
plt.figure(figsize=(8,4))
sb.countplot(x='STATUS', data=dd, palette='pastel')
plt.title("STATUS Distribution")
plt.show()

# %% [markdown]
# ### What is the distribution of Annual Income?

# %%
plt.figure(figsize=(7,4))
plt.hist(dd['AMT_INCOME_TOTAL'], bins=30)
plt.title("Annual Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### What is the age distribution of customers?

# %%
plt.figure(figsize=(8,5))
plt.hist(dd['Age'], bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution")
plt.show()

# %%
dd.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# MONTHS_BALANCE           int64
# STATUS                  object
# CR_STATUS                int64
# Age                      int64
# dtype: object

# %% [markdown]
# ### How is Employment Length distributed?

# %%
plt.hist(dd['DAYS_EMPLOYED'], bins=30)
plt.title("Annual Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### What is the distribution of Family Member Count?

# %%
plt.figure(figsize=(6,4))
sb.countplot(x='CNT_FAM_MEMBERS', data=dd, palette='viridis')
plt.title("Family Member Count Distribution")
plt.show()

# %% [markdown]
# ### How are categorical features distributed?

# %% [markdown]
# ### How are categorical features distributed?

# %%
dd['CR_STATUS'].value_counts()
# Out:
# CR_STATUS
# 0    774887
# 1      2828
# Name: count, dtype: int64

# %%
dd.STATUS.value_counts()
# Out:
# STATUS
# C    329536
# 0    290654
# X    145950
# 1      8747
# 5      1527
# 2       801
# 3       286
# 4       214
# Name: count, dtype: int64

# %%
dd.OCCUPATION_TYPE.value_counts()
# Out:
# OCCUPATION_TYPE
# Unknown                  240048
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
dd.NAME_HOUSING_TYPE.value_counts()
# Out:
# NAME_HOUSING_TYPE
# House / apartment      697151
# With parents            35735
# Municipal apartment     24640
# Rented apartment        10898
# Office apartment         5636
# Co-op apartment          3655
# Name: count, dtype: int64

# %%
dd.NAME_FAMILY_STATUS.value_counts()
# Out:
# NAME_FAMILY_STATUS
# Married                 546619
# Single / not married     94335
# Civil marriage           60342
# Separated                45255
# Widow                    31164
# Name: count, dtype: int64

# %%
dd.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# MONTHS_BALANCE           int64
# STATUS                  object
# CR_STATUS                int64
# Age                      int64
# dtype: object

# %%
dd.NAME_EDUCATION_TYPE.value_counts()
# Out:
# NAME_EDUCATION_TYPE
# Secondary / secondary special    524261
# Higher education                 213633
# Incomplete higher                 30329
# Lower secondary                    8655
# Academic degree                     837
# Name: count, dtype: int64

# %% [markdown]
# ### How does Annual Income vary between good(0)and bad(1)credit customers?

# %%
sb.boxplot(x=dd['CR_STATUS'], y=dd['AMT_INCOME_TOTAL'])
plt.title("Income vs Credit Risk")
plt.show()

# %% [markdown]
# ### What is the correlation between numerical features?

# %%
dd.FLAG_MOBIL.fillna(0)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 777710    1
# 777711    1
# 777712    1
# 777713    1
# 777714    1
# Name: FLAG_MOBIL, Length: 777715, dtype: int64

# %%
b = dd[['CNT_CHILDREN','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_PHONE','FLAG_EMAIL','MONTHS_BALANCE','CR_STATUS']].corr()
b
# Out:
#                 CNT_CHILDREN  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_PHONE  \
# CNT_CHILDREN        1.000000    0.356177      -0.228945   -0.018882
# DAYS_BIRTH          0.356177    1.000000      -0.608856   -0.026717
# DAYS_EMPLOYED      -0.228945   -0.608856       1.000000   -0.013817
# FLAG_PHONE         -0.018882   -0.026717      -0.013817    1.000000
# FLAG_EMAIL          0.015726    0.100945      -0.082474    0.011901
# MONTHS_BALANCE      0.000913    0.035756      -0.004222   -0.005120
# CR_STATUS          -0.000705   -0.005145       0.003697    0.007213
#
#                 FLAG_EMAIL  MONTHS_BALANCE  CR_STATUS
# CNT_CHILDREN      0.015726        0.000913  -0.000705
# DAYS_BIRTH        0.100945        0.035756  -0.005145
# DAYS_EMPLOYED    -0.082474       -0.004222   0.003697
# FLAG_PHONE        0.011901       -0.005120   0.007213
# FLAG_EMAIL        1.000000        0.005288  -0.003054
# MONTHS_BALANCE    0.005288        1.000000  -0.004405
# ...

# %%
plt.figure(figsize=[15,8])
sb.heatmap(b, annot=True)
plt.show()

# %% [markdown]
# ### Are there extreme outliers in Annual Income?

# %%
sb.boxplot(dd.AMT_INCOME_TOTAL)
plt.show()

# %% [markdown]
# ### How does credit risk vary by Income Type?

# %%
plt.figure(figsize=(8,5))
sb.countplot(x=dd['NAME_INCOME_TYPE'] )
plt.title("Credit Risk by Income Type")
plt.xlabel("Income Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Machine Learning

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
dd.CODE_GENDER = label.fit_transform(dd.CODE_GENDER)
dd.FLAG_OWN_CAR = label.fit_transform(dd.FLAG_OWN_CAR)
dd.FLAG_OWN_REALTY = label.fit_transform(dd.FLAG_OWN_REALTY)
dd.NAME_INCOME_TYPE = label.fit_transform(dd.NAME_INCOME_TYPE)
dd.NAME_EDUCATION_TYPE = label.fit_transform(dd.NAME_EDUCATION_TYPE)
dd.NAME_FAMILY_STATUS = label.fit_transform(dd.NAME_FAMILY_STATUS)
dd.NAME_HOUSING_TYPE = label.fit_transform(dd.NAME_HOUSING_TYPE)
dd.OCCUPATION_TYPE = label.fit_transform(dd.OCCUPATION_TYPE)
dd.STATUS = label.fit_transform(dd.STATUS)

# %%
dd
# Out:
#              ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804            1             1                1             0
# 1       5008804            1             1                1             0
# 2       5008804            1             1                1             0
# 3       5008804            1             1                1             0
# 4       5008804            1             1                1             0
# ...         ...          ...           ...              ...           ...
# 777710  5150337            1             0                1             0
# 777711  5150337            1             0                1             0
# 777712  5150337            1             0                1             0
# 777713  5150337            1             0                1             0
# 777714  5150337            1             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# ...

# %%
X = dd.drop('CR_STATUS', axis=1).values
y = dd['CR_STATUS'].values

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(Xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(Xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(155543,))

# %%
yp = model.predict(Xtest)
yp
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(155543,))

# %%
from sklearn.metrics import accuracy_score

scr1 = accuracy_score(ytest,yp)
scr1
# Out:
# 0.996071825797368

# %% [markdown]
# ### With parameters

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = LogisticRegression(
    penalty='l2',
    C=1.0,
    solver='liblinear',
    max_iter=1000,
    class_weight='balanced'
)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, penalty='l2',
#                    solver='liblinear')

# %%
from sklearn.metrics import accuracy_score
scr = accuracy_score(y_test,yp)
scr*100
# Out:
# 99.63932803147682

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
Xtrain1,Xtest1,ytrain1,ytest1 = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(Xtrain1, ytrain1)
# Out:
# RandomForestClassifier()

# %%
yp_rf = rf_model.predict(Xtest1)
yp_rf
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(155543,))

# %%
from sklearn.metrics import accuracy_score

# %%
scr1 = accuracy_score(ytest1, yp_rf)
scr1
# Out:
# 0.999980712728956

# %% [markdown]
# ### With hyperparameters

# %%
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight='balanced',
    random_state=42
)

# %%
rf_model.fit(Xtrain, ytrain)

# %%
yp_rf1 = rf_model.predict(Xtest)
yp_rf1

# %%
from sklearn.metrics import accuracy_score

# %%
scr2 = accuracy_score(ytest, yp_rf)
scr2

# %%
from sklearn.model_selection import train_test_split
Xtrain2,Xtest2,ytrain2,ytest2 = train_test_split(X,y,test_size=0.2)

# %%
from xgboost import XGBClassifier

# %%
xgb_model = XGBClassifier()

# %%
xgb_model.fit(Xtrain2, ytrain2)

# %%
yp_xgb = xgb_model.predict(Xtest2)

# %%
yp_xgb

# %%
from sklearn.metrics import accuracy_score

# %%
scr3 = accuracy_score(y_test, yp_xgb)
scr3

# %% [markdown]
# ### With Hyperparameters

# %%
xgb_model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='logloss'
)

# %%
xgb_model.fit(Xtrain2, ytrain2)

# %%
yp_xgb = xgb_model.predict(Xtest2)
yp_xgb

# %%
scr4 = accuracy_score(ytest2, yp_xgb)
scr4
